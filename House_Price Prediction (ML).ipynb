# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
HP = pd.read_csv("C:\\AI(ml&dl)\\jupiter(machine learning)\Projetcs(ML)\\11_HousePricePredictionusing_LinearRegression\\dataset.csv")
HP.head()
# Out:
#     area   price
# 0   8450  208500
# 1   9600  181500
# 2  11250  223500
# 3   9550  140000
# 4  14260  250000

# %%
HP.shape
# Out:
# (1460, 2)

# %%
HP.isna().sum()
# Out:
# area     0
# price    0
# dtype: int64

# %%
sns.heatmap(HP.corr(),annot=True)
plt.show()

# %%
x=HP.iloc[:,:-1]
y=HP.iloc[:,-1]
x.shape
# Out:
# (1460, 1)

# %%
y.shape
# Out:
# (1460,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 42)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
pred = model.predict(x_test)

# %%
coeff_df = pd.DataFrame(model.coef_,x.columns,columns=['coefficient'])
coeff_df
# Out:
#       coefficient
# area     1.870895

# %%
plt.scatter(y_test,pred)

# %%
sns.distplot((y_test,pred),bins = 50)
plt.show()
# Out:
# C:\Users\HAI\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
x=6660
LandAreaInSqFt=[[x]]
result = model.predict(LandAreaInSqFt)
print(result)
# Out:
# [174065.85355128]
# C:\Users\HAI\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
